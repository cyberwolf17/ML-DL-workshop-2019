# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import ndimage
from sklearn import cluster
image = ndimage.imread("parrot.jpg")
plt.figure(figsize = (15,8))
plt.imshow(image)
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/ipykernel/__main__.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.

# %%
image.shape
# Out:
# (1080, 1080, 3)

# %%
x,y,z = image.shape
image_2d = image.reshape(x*y,z)
image_2d.shape
# Out:
# (1166400, 3)

# %%
kmeans_cluster = cluster.KMeans(n_clusters=50)
kmeans_cluster.fit(image_2d)
cluster_centers = kmeans_cluster.cluster_centers_
cluster_labels = kmeans_cluster.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d9ec0123d1d8> in <module>()
# ----> 1 kmeans_cluster = cluster.KMeans(n_clusters=50)
#       2 kmeans_cluster.fit(image_2d)
#       3 cluster_centers = kmeans_cluster.cluster_centers_
#       4 cluster_labels = kmeans_cluster.labels_
#
# NameError: name 'cluster' is not defined

# %%
plt.figure(figsize=(15,8))
plt.imshow(cluster_centers[cluster_labels].reshape(x,y,z))
